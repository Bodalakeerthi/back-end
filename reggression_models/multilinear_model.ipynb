# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # LOAD DATASET

# %%
# Load dataset
df = pd.read_csv("Housing.csv")

# %% [markdown]
# # ENCODING BY USING LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
catcol=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']
for col in catcol:
    df[col]=le.fit_transform(df[col])

# %% [markdown]
# # DATA PREPROCESSING

# %%
x1 = df.drop(columns=['price'])  
y1 = df['price']                 
x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=0.3, random_state=0)

# %% [markdown]
# # MODEL TRAINING

# %%
model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)

# %% [markdown]
# # EVALUATING OF THE MODEL

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
r2score=r2_score(y_test,y_pred)
print(f"  mse:{mse}, r2score:{r2score}")
# Out:
#   mse:959110878780.88, r2score:0.723501522320035

# %% [markdown]
# # VISUALIZATION

# %%
# Plotting Actual vs Predicted
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='red', alpha=0.7)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')  # Line for perfect prediction
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted for Test Data')
plt.show()
